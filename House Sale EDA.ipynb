# %% [markdown]
# ## House Sales

# %% [markdown]
# About: House Sales <br>
# Objective:
# Exploration Data Analysis berisi :
# 1. Descriptive Statistic Analysist
# 2. Keterpusatan Data
# 3. Penyebaran data

# %% [markdown]
# Import Library

# %%
import pandas as pd # untuk data set
import numpy as np #library untuk nilai 
import seaborn as sns # untuk visualisasi menggunakan seaborn
import matplotlib.pyplot as plt # untuk diagram basic

# %% [markdown]
# Import data

# %%
df=pd.read_csv(r"C:\Users\asus\Desktop\Data Scientist\porto\kc_house_data.csv\kc_house_data.csv")

# %% [markdown]
# ## 1. Data Understanding

# %% [markdown]
# 1. Ukuran Data
# 2. Head and tail
# 3. tipe data
# 4. penjelasan data (describe)

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
print (df.shape)
# Out:
# (21613, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# dari data tidak menunjukan missing value atau nilai null

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# ## 2.Data Preparation

# %% [markdown]
# 1. Buang kolom yang kurang relevan (bila perlu)
# 2. penamaan kolom yang sesuai
# 3. identifikasi nilai yang duplikat
# 4. mencari nilai null

# %% [markdown]
# Mengecek isi kolom pada tabel dan tidak diperlukan untuk membuang kolom dikarenakan informasi yang diberikan bisa menjadi informasi tambahan dan menghapus kolom id serta date

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# Setelah dicek tidak ada nilai null atau missing value

# %% [markdown]
# ## Analysis Descriptive

# %% [markdown]
# Analisis deskriptif untuk harga
# 1. mean , median, modus
# 2. Q1,Q2, dan interquartile
# 3. range, standar deviasi, dan variance

# %%
print ('Nilai rata rata harga :',round(df['price'].mean(),2))
print ('Nilai median harga :',df['price'].median())
print ('Nilai modus harga :',df['price'].mode())
# Out:
# Nilai rata rata harga : 540088.14
# Nilai median harga : 450000.0
# Nilai modus harga : 0    350000.0
# 1    450000.0
# Name: price, dtype: float64

# %%
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
interquartile = Q3-Q1
print ('Nilai Q1 harga :',Q1)
print ('Nilai Q1 harga :',Q3)
print ('Nilai Interquartile harga :',Q3-Q1)
# Out:
# Nilai Q1 harga : 321950.0
# Nilai Q1 harga : 645000.0
# Nilai Interquartile harga : 323050.0

# %%
price_max = df['price'].max()
price_min = df['price'].min()
price_range = price_max-price_min

print ('Nilai Harga Terendah',price_min)
print ('Nilai Harga Tertinggi',price_max)
print ('Nilai Range Harga :', price_range)
print ('Nilai Standar Deviasi Harga :', round(df['price'].std(),2))
print ('Nilai Variance Harga ;', round(df['price'].var(),2))
# Out:
# Nilai Harga Terendah 75000.0
# Nilai Harga Tertinggi 7700000.0
# Nilai Range Harga : 7625000.0
# Nilai Standar Deviasi Harga : 367127.2
# Nilai Variance Harga ; 134782378397.25

# %% [markdown]
# kita coba lihat distribus dari harga rumah. 1 variabel maka menggunakan histogram

# %%
plt.figure(figsize=(10,5))
sns.histplot(x=df['price'],data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df,
            x=df['price'])
plt.show()

# %% [markdown]
# Nilai batas atas dan batas bawah outlier adalah sbb :

# %%
batas_bawah_outlier = Q1-(interquartile*1,5)
batas_atas_outlier = Q3+(interquartile*1,5)
print ('Batas bawah  ;', batas_bawah_outlier)
print ('Batas atas  ;', batas_atas_outlier)
# Out:
# Batas bawah  ; [ -1100. 321945.]
# Batas atas  ; [968050. 645005.]

# %% [markdown]
# dari data histogram dan boxplot terlihat perbedaan yang cukup signifikan mengenai harga dan terdapat pencilan ke kanan harga sehingga menarik rata rata ke kanan. <br>
# hal ini kemungkinan dipengaruhi oleh fasilitas dan tahun dibangun rumah tersebut.

# %% [markdown]
# ## Korelasi Harga dengan Variabel lain

# %%
corr_yearbuilt_price = df['price'].corr(df['yr_built'])
sns.heatmap(data=[[corr_yearbuilt_price]], annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# jika dilihat hubungan antara harga dengan tahun dibangun ada korelasi positif lemah yaitu sebesar 0.05 namun tidak menggambarkan sebab akibat

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21613 non-null  float64
#  1   bedrooms       21613 non-null  int64
#  2   bathrooms      21613 non-null  float64
#  3   sqft_living    21613 non-null  int64
#  4   sqft_lot       21613 non-null  int64
#  5   floors         21613 non-null  float64
#  6   waterfront     21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   grade          21613 non-null  int64
#  10  sqft_above     21613 non-null  int64
#  11  sqft_basement  21613 non-null  int64
#  12  yr_built       21613 non-null  int64
#  13  yr_renovated   21613 non-null  int64
#  14  zipcode        21613 non-null  int64
#  15  lat            21613 non-null  float64
#  16  long           21613 non-null  float64
# ...

# %%
all_corr = df.corr()

# %%
plt.figure (figsize=(14,14))
sns.heatmap(data=all_corr,
            annot=True,
            cmap='coolwarm',
            fmt=".2f")
plt.show()

# %% [markdown]
# dari data diatas menunjukan bahwa harga memiliki korelasi yang positif pada semua atribut dengan ketentuan <br>
#
# 0.81-1 korelasi sempurna : tidak ada <br>
#
# 0.61-0.8 korelasi kuat :
# - sqft_above
# - grade
# - sqft living <br>
#
# 0.41-0.6 korelasi sedang :
# - bathrooms
# - view
# - sqft_living15 <br>
#
# 0.00-0.4 korelasi lemah :
# - sisanya

# %% [markdown]
# Bagaimana gambaran korelasi antara harga dengan variabel yang memiliki korelasi kuat

# %%
plt.figure(figsize = (5,5))
sns.regplot(y='price',
                x='sqft_above',
                data=df,
               line_kws ={'color':'red'})
plt.title('Nilai antara Harga dengan sqft above')
# Out:
# Text(0.5, 1.0, 'Nilai antara Harga dengan sqft above')

# %%
plt.figure(figsize = (5,5))
sns.regplot(y='price',
                x='grade',
                data=df,
               line_kws ={'color':'red'})
plt.title('Nilai antara Harga dengan grade')
plt.show()

# %%
plt.figure(figsize = (5,5))
sns.regplot(y='price',
            x='sqft_living15',
            data=df,
           line_kws ={'color':'red'})
plt.title('Nilai antara Harga dengan sqft_living15')
# Out:
# Text(0.5, 1.0, 'Nilai antara Harga dengan sqft_living15')

# %% [markdown]
# ## Kausalitas antara harga dengan Grade

# %% [markdown]
# - Nama penelitian : Hubungan kausalitas antara harga dengan Grade Rumah
# - matrix yang digunakan : harga dan grade
# - uji normalitas : menggunakan shapiro wilk dan kolmogorof smirnov untuk membandingkan keduanya
# - uji kausalitas : menggunakan biserial karena 1 data ordinal (grade) dan 1 data ratio

# %% [markdown]
# ## Uji normalitas

# %% [markdown]
# 1. Shapiro Wilk

# %%
from scipy.stats import shapiro #mengambil uji shapiro wilk pada scipy.stats

H0 = 'Data terdistribusi Normal atau terima H0'
H1 = 'Data tidak terdistribusi Normal atau terima H1'

stat, p_value_sw = shapiro(df['price']) #uji normalitas shapiro wilk

print (stat, p_value_sw)

if p_value_sw < 0.05:
    print (H0)
else :
    print (H1)
# Out:
# 0.7120144367218018 0.0
# Data terdistribusi Normal atau terima H0
# C:\Users\asus\anaconda3\Lib\site-packages\scipy\stats\_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# 2. Uji Kolmogorov Smirnov

# %%
from scipy.stats import kstest #mengambil uji kolmogorov smirnov pada scipy.stats

H0 = 'Data terdistribusi Normal atau terima H0'
H1 = 'Data tidak terdistribusi Normal atau terima H1'

stat, p_value_ks = kstest(df['price'],'norm') #uji normalitas kolmogorov smirnov

print (stat, p_value_ks)

if p_value_sw < 0.05:
    print (H0)
else :
    print (H1)
# Out:
# 1.0 0.0
# Data terdistribusi Normal atau terima H0

# %% [markdown]
# dari 2 uji diatas keseluruhan menunjukan data terdistribusi normal

# %%
from scipy.stats import pointbiserialr

H0 = 'Tidak ada hubungan pengaruh antara grade dengan harga'
H1 = 'Ada hubungan pengaruh antara grade dengan harga'

# %%
df['grade'].value_counts().sort_index(ascending=True)
# Out:
# grade
# 1        1
# 3        3
# 4       29
# 5      242
# 6     2038
# 7     8981
# 8     6068
# 9     2615
# 10    1134
# 11     399
# 12      90
# 13      13
# Name: count, dtype: int64
